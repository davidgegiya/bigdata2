# %%
import trimap
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
import matplotlib.pyplot as plt
from ucimlrepo import fetch_ucirepo 
from sklearn.preprocessing import OneHotEncoder
  
# DATESET_ID = 82
DATESET_ID = 90
# fetch dataset 
post_operative_patient = fetch_ucirepo(id=DATESET_ID) 
  
# data (as pandas dataframes) 
X = post_operative_patient.data.features 
y = post_operative_patient.data.targets

# Преобразование категориальных признаков в числовые с помощью One-Hot Encoding
encoder = OneHotEncoder(sparse_output=False)
X_encoded = encoder.fit_transform(X)
# Нормализация данных
scaler = MinMaxScaler((1,10))
X_scaled = scaler.fit_transform(X_encoded)

settings = [
    {
        "n_inliers": 12,
        "n_outliers": 4,
        "lr": 0.1,
    },
    {
        "n_inliers": 16,
        "n_outliers": 4,
        "lr": 0.1,
    },
    {
        "n_inliers": 12,
        "n_outliers": 8,
        "lr": 0.1,
    },
    {
        "n_inliers": 12,
        "n_outliers": 4,
        "lr": 0.5,
    },
    {
        "n_inliers": 5,
        "n_outliers": 2,
        "lr": 0.1,
    },
    {
        "n_inliers": 20,
        "n_outliers": 10,
        "lr": 0.1,
    },
]

# Создаем фигуру для 6 подграфиков
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for i, ax in enumerate(axes.flat):
    reducer = trimap.TRIMAP(**settings[i])
    X_umap = reducer.fit_transform(X_scaled)
    
    # Отображаем результат на подграфике
    scatter = ax.scatter(X_umap[:, 0], X_umap[:, 1], c=pd.factorize(y.squeeze())[0], cmap='tab10', alpha=0.7)
    ax.set_title(f"UMAP n_inliers={settings[i]['n_inliers']}, lr={settings[i]['lr']}")
    
# plt.colorbar(scatter, ax=axes.ravel().tolist(), orientation='horizontal', fraction=0.05, pad=0.08)

# Отображаем графики
plt.tight_layout()
plt.show()
# Out:
# /var/folders/7y/_9gxx1r554j8172k7b6gy8080000gn/T/ipykernel_42797/644635172.py:71: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import trimap
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
import matplotlib.pyplot as plt
from ucimlrepo import fetch_ucirepo 
from sklearn.preprocessing import OneHotEncoder
  
# DATESET_ID = 82
DATESET_ID = 90
# fetch dataset 
post_operative_patient = fetch_ucirepo(id=DATESET_ID) 
  
# data (as pandas dataframes) 
X = post_operative_patient.data.features 
y = post_operative_patient.data.targets

# Преобразование категориальных признаков в числовые с помощью One-Hot Encoding
encoder = OneHotEncoder(sparse_output=False)
X_encoded = encoder.fit_transform(X)
# Нормализация данных
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_encoded)

settings = [
    {
        "n_inliers": 12,
        "n_outliers": 4,
        "lr": 0.1,
    },
    {
        "n_inliers": 16,
        "n_outliers": 4,
        "lr": 0.1,
    },
    {
        "n_inliers": 12,
        "n_outliers": 8,
        "lr": 0.1,
    },
    {
        "n_inliers": 12,
        "n_outliers": 4,
        "lr": 0.5,
    },
    {
        "n_inliers": 5,
        "n_outliers": 2,
        "lr": 0.1,
    },
    {
        "n_inliers": 20,
        "n_outliers": 10,
        "lr": 0.1,
    },
]

# Создаем фигуру для 6 подграфиков
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for i, ax in enumerate(axes.flat):
    reducer = trimap.TRIMAP(**settings[i])
    X_umap = reducer.fit_transform(X_scaled)
    
    # Отображаем результат на подграфике
    scatter = ax.scatter(X_umap[:, 0], X_umap[:, 1], c=pd.factorize(y.squeeze())[0], cmap='tab10', alpha=0.7)
    ax.set_title(f"UMAP n_inliers={settings[i]['n_inliers']}, lr={settings[i]['lr']}")
    
# plt.colorbar(scatter, ax=axes.ravel().tolist(), orientation='horizontal', fraction=0.05, pad=0.08)

# Отображаем графики
plt.tight_layout()
plt.show()

# %%
import trimap
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
import matplotlib.pyplot as plt
from ucimlrepo import fetch_ucirepo 
from sklearn.preprocessing import OneHotEncoder
  
# DATESET_ID = 82
DATESET_ID = 90
# fetch dataset 
post_operative_patient = fetch_ucirepo(id=DATESET_ID) 
  
# data (as pandas dataframes) 
X = post_operative_patient.data.features 
y = post_operative_patient.data.targets

# Преобразование категориальных признаков в числовые с помощью One-Hot Encoding
encoder = OneHotEncoder(sparse_output=False)
X_encoded = encoder.fit_transform(X)
# Нормализация данных
scaler = RobustScaler()
X_scaled = scaler.fit_transform(X_encoded)

settings = [
    {
        "n_inliers": 12,
        "n_outliers": 4,
        "lr": 0.1,
    },
    {
        "n_inliers": 16,
        "n_outliers": 4,
        "lr": 0.1,
    },
    {
        "n_inliers": 12,
        "n_outliers": 8,
        "lr": 0.1,
    },
    {
        "n_inliers": 12,
        "n_outliers": 4,
        "lr": 0.5,
    },
    {
        "n_inliers": 5,
        "n_outliers": 2,
        "lr": 0.1,
    },
    {
        "n_inliers": 20,
        "n_outliers": 10,
        "lr": 0.1,
    },
]

# Создаем фигуру для 6 подграфиков
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for i, ax in enumerate(axes.flat):
    reducer = trimap.TRIMAP(**settings[i])
    X_umap = reducer.fit_transform(X_scaled)
    
    # Отображаем результат на подграфике
    scatter = ax.scatter(X_umap[:, 0], X_umap[:, 1], c=pd.factorize(y.squeeze())[0], cmap='tab10', alpha=0.7)
    ax.set_title(f"UMAP n_inliers={settings[i]['n_inliers']}, lr={settings[i]['lr']}")
    
# plt.colorbar(scatter, ax=axes.ravel().tolist(), orientation='horizontal', fraction=0.05, pad=0.08)

# Отображаем графики
plt.tight_layout()
plt.show()
