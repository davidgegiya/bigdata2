# %%
from umap import umap_ as UMAP
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
import matplotlib.pyplot as plt
from ucimlrepo import fetch_ucirepo 
from sklearn.preprocessing import OneHotEncoder
  
# DATESET_ID = 82
DATESET_ID = 90
# fetch dataset 
post_operative_patient = fetch_ucirepo(id=DATESET_ID) 
  
# data (as pandas dataframes) 
X = post_operative_patient.data.features 
y = post_operative_patient.data.targets

# Преобразование категориальных признаков в числовые с помощью One-Hot Encoding
encoder = OneHotEncoder(sparse_output=False)
X_encoded = encoder.fit_transform(X)
# Нормализация данных
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_encoded)

settings = [
    {
        "n_neighbors": 15,
        "min_dist": 0.1,
    },
    {
        "n_neighbors": 30,
        "min_dist": 0.2,
    },
    {
        "n_neighbors": 5,
        "min_dist": 0.05,
    },
    {
        "n_neighbors": 40,
        "min_dist": 0.15,
    },
    {
        "n_neighbors": 50,
        "min_dist": 0.1,
    },
    {
        "n_neighbors": 20,
        "min_dist": 0.01,
    },
]

# Создаем фигуру для 6 подграфиков
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for i, ax in enumerate(axes.flat):
    reducer = UMAP.UMAP(random_state=42, **settings[i])
    X_umap = reducer.fit_transform(X_scaled)
    
    # Отображаем результат на подграфике
    scatter = ax.scatter(X_umap[:, 0], X_umap[:, 1], c=pd.factorize(y.squeeze())[0], cmap='tab10', alpha=0.7)
    ax.set_title(f"UMAP n_neighbors={settings[i]['n_neighbors']}, min_dist={settings[i]['min_dist']}")
    
# plt.colorbar(scatter, ax=axes.ravel().tolist(), orientation='horizontal', fraction=0.05, pad=0.08)

# Отображаем графики
plt.tight_layout()
plt.show()
# Out:
# /Users/davitgegia/study/9sem/python/1/pythonProject/.venv/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/davitgegia/study/9sem/python/1/pythonProject/.venv/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/davitgegia/study/9sem/python/1/pythonProject/.venv/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/davitgegia/study/9sem/python/1/pythonProject/.venv/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/davitgegia/study/9sem/python/1/pythonProject/.venv/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/davitgegia/study/9sem/python/1/pythonProject/.venv/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
from umap import umap_ as UMAP
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
import matplotlib.pyplot as plt
from ucimlrepo import fetch_ucirepo 
from sklearn.preprocessing import OneHotEncoder
  
# DATESET_ID = 82
DATESET_ID = 90
# fetch dataset 
post_operative_patient = fetch_ucirepo(id=DATESET_ID) 
  
# data (as pandas dataframes) 
X = post_operative_patient.data.features 
y = post_operative_patient.data.targets

# Преобразование категориальных признаков в числовые с помощью One-Hot Encoding
encoder = OneHotEncoder(sparse_output=False)
X_encoded = encoder.fit_transform(X)
# Нормализация данных
scaler = MinMaxScaler((1,10))
X_scaled = scaler.fit_transform(X_encoded)

settings = [
    {
        "n_neighbors": 15,
        "min_dist": 0.1,
    },
    {
        "n_neighbors": 30,
        "min_dist": 0.2,
    },
    {
        "n_neighbors": 5,
        "min_dist": 0.05,
    },
    {
        "n_neighbors": 40,
        "min_dist": 0.15,
    },
    {
        "n_neighbors": 50,
        "min_dist": 0.1,
    },
    {
        "n_neighbors": 20,
        "min_dist": 0.01,
    },
]

# Создаем фигуру для 6 подграфиков
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for i, ax in enumerate(axes.flat):
    reducer = UMAP.UMAP(random_state=42, **settings[i])
    X_umap = reducer.fit_transform(X_scaled)
    
    # Отображаем результат на подграфике
    scatter = ax.scatter(X_umap[:, 0], X_umap[:, 1], c=pd.factorize(y.squeeze())[0], cmap='tab10', alpha=0.7)
    ax.set_title(f"UMAP n_neighbors={settings[i]['n_neighbors']}, min_dist={settings[i]['min_dist']}")
    
# plt.colorbar(scatter, ax=axes.ravel().tolist(), orientation='horizontal', fraction=0.05, pad=0.08)

# Отображаем графики
plt.tight_layout()
plt.show()
# Out:
# /Users/davitgegia/study/9sem/python/1/pythonProject/.venv/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/davitgegia/study/9sem/python/1/pythonProject/.venv/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/davitgegia/study/9sem/python/1/pythonProject/.venv/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/davitgegia/study/9sem/python/1/pythonProject/.venv/lib/python3.9/site-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/davitgegia/study/9sem/python/1/pythonProject/.venv/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/davitgegia/study/9sem/python/1/pythonProject/.venv/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/davitgegia/study/9sem/python/1/pythonProject/.venv/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
from umap import umap_ as UMAP
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
import matplotlib.pyplot as plt
from ucimlrepo import fetch_ucirepo 
from sklearn.preprocessing import OneHotEncoder
  
# DATESET_ID = 82
DATESET_ID = 90
# fetch dataset 
post_operative_patient = fetch_ucirepo(id=DATESET_ID) 
  
# data (as pandas dataframes) 
X = post_operative_patient.data.features 
y = post_operative_patient.data.targets

# Преобразование категориальных признаков в числовые с помощью One-Hot Encoding
encoder = OneHotEncoder(sparse_output=False)
X_encoded = encoder.fit_transform(X)
# Нормализация данных
scaler = RobustScaler()
X_scaled = scaler.fit_transform(X_encoded)

settings = [
    {
        "n_neighbors": 15,
        "min_dist": 0.1,
    },
    {
        "n_neighbors": 30,
        "min_dist": 0.2,
    },
    {
        "n_neighbors": 5,
        "min_dist": 0.05,
    },
    {
        "n_neighbors": 40,
        "min_dist": 0.15,
    },
    {
        "n_neighbors": 50,
        "min_dist": 0.1,
    },
    {
        "n_neighbors": 20,
        "min_dist": 0.01,
    },
]

# Создаем фигуру для 6 подграфиков
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for i, ax in enumerate(axes.flat):
    reducer = UMAP.UMAP(random_state=42, **settings[i])
    X_umap = reducer.fit_transform(X_scaled)
    
    # Отображаем результат на подграфике
    scatter = ax.scatter(X_umap[:, 0], X_umap[:, 1], c=pd.factorize(y.squeeze())[0], cmap='tab10', alpha=0.7)
    ax.set_title(f"UMAP n_neighbors={settings[i]['n_neighbors']}, min_dist={settings[i]['min_dist']}")
    
# plt.colorbar(scatter, ax=axes.ravel().tolist(), orientation='horizontal', fraction=0.05, pad=0.08)

# Отображаем графики
plt.tight_layout()
plt.show()
# Out:
# /Users/davitgegia/study/9sem/python/1/pythonProject/.venv/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/davitgegia/study/9sem/python/1/pythonProject/.venv/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/davitgegia/study/9sem/python/1/pythonProject/.venv/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/davitgegia/study/9sem/python/1/pythonProject/.venv/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/davitgegia/study/9sem/python/1/pythonProject/.venv/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/davitgegia/study/9sem/python/1/pythonProject/.venv/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
